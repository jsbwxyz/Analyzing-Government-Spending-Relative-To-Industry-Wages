# %% [markdown]
# Jeremy Barton <br>
# DSC-540-T301 <br>
# 03.08.2026

# %% [markdown]
# # Analyzing Government Spending Relative to Industry Wages: A Multi-Source Data Pipeline

# %% [markdown]
# ## Introduction

# %% [markdown]
# The goal of this notebook is to collect, store and visualize public government spending and wage data. Each of the three sources used comes from a different extraction method; treasury data is from a web table on the Monthly Treasury Statement at https://fiscaldata.treasury.gov loaded in HTML, spending data is from the https://USASpending.gov API, and wage data is from a flat file on the Bureau of Labor Statistics website at https://www.bls.gov/cew/downloadable-data-files.htm under "Annual Averages" for the year 2024.
#
# By the end, wages and award amounts are plotted by industry to visualize how federal spending compares to what workers in those industries actually earn. The analysis is scoped to Connecticut for 2024. A reflection on data transformations made and the ethical considerations of working with public government data concludes the notebook.

# %% [markdown]
# ## Step 1: Gathering the Sources

# %% [markdown]
# ### `treasury_df`

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# #### Preprocessing

# %% [markdown]
# We could pass a file handler directly to the constructor of the BeautifulSoup
# object and it will read the contents from the file that the handler is attached to.
#
# BeautifulSoup allows us to extract tags of the same type. Below is an example of using the `table` method to pull tags related to tables on the web. `<tr>`, `<td>`, `<th>`...

# %%
# Open the file
with open("data/Monthly Treasury Statement.html") as mts:
    soup = BeautifulSoup(mts)
    print(type(soup))

# Find paragraphs
all_ps = soup.find_all('p')
table = soup.table # Find tables
children = table.children # Find child elements of table
des = table.descendants # Find table descendants
# Out:
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# #### Extraction

# %% [markdown]
# In the first attempt to extract data from the data table, only the first table was returned. The class being accessed contains multiple tables. Inspecting the page can help identify the right parts of a webpage to pull the correct information. This is a more direct approach, as tables can be held in 'classes' which can be accessed to find data tables.

# %% [markdown]
# Now we will use the .select() method from `bs4` to search inside a DIV for tables.

# %%
# Inside the .select() is where the div we want to search
#   for is placed.
tables = soup.select(
    "div.data-table-module--overlayContainerNoFooter--a46b8 table"
)

table = []
# Save output for use in next step
# Creating a loop to pick up all tables in the DIV
for table in tables:
    
     table.append(table.prettify())

# Making "table" equal to tables[1] will extract the
#   uneeded download file table.
table = tables[0]
# print(table)

# %% [markdown]
# #### Conversion

# %%
import pandas as pd

# %% [markdown]
# Separate headers from the data.

# %%
rows = table.find_all('tr')[1:]
# Correct: headers is a <tr> tag
headers = table.find('tr')  # do NOT call getText() here
col_headers = [th.getText() for th in headers.findAll('th')]
# col_headers
# Out:
# /tmp/ipykernel_24776/3079059324.py:4: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   col_headers = [th.getText() for th in headers.findAll('th')]

# %%
data_rows = []

# Clean row data to only include text inside 'td' or 'th' tags.
for row in rows:
    
    cells = [cell.get_text(strip=True) for cell in row.find_all(['td', 'th'])]
    data_rows.append(cells)
# data_rows

# %% [markdown]
# Carefully place the row data into a pandas dataframe.

# %%
treasury_data = [[td.getText() for td in tr.findAll('td')] \
            for tr in rows]
# df_data
# Out:
# /tmp/ipykernel_24776/2943969321.py:1: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   treasury_data = [[td.getText() for td in tr.findAll('td')] \

# %%
treasury_df = pd.DataFrame(treasury_data, columns=col_headers)

# strip whitespace from headers
treasury_df.columns = treasury_df.columns.str.strip()

treasury_df.head()
# Out:
#   Record Datemm/dd/yyyy - mm/dd/yyyy Parent ID​ Classification ID​  \
# 0                         12/31/2025                      57633926
# 1                         12/31/2025   57633926           57633931
# 2                         12/31/2025   57633926           57633935
# 3                         12/31/2025   57633926           57633940
# 4                         12/31/2025   57633926           57633942
#
#   Classification Description​ Current Month Gross Receipts Amount​  \
# 0                     FY 2025
# 1                     October                  $326,770,236,058.10
# 2                    November                  $301,754,299,812.79
# 3                    December                  $454,414,708,491.47
# 4                     January                  $513,294,342,651.93
#
#   Current Month Gross Outlay Amount​ Current Month Deficit Surplus Amount​  \
# 0
# 1                $584,220,273,025.31                   $257,450,036,967.21
# 2                $668,517,135,060.47                   $366,762,835,247.68
# 3                $541,146,327,504.76                    $86,731,619,013.29
# 4                $641,934,549,325.42                   $128,640,206,673.49
#
#   Table Number​ Source Line Number​ Print Order Sequence Number​  ...  \
# 0             1                   1                            1  ...
# 1             1                   2                            2  ...
# 2             1                   3                            3  ...
# 3             1                   4                            4  ...
# 4             1                   5                            5  ...
#
#   Data Type Code​ Record Type Code​ Sequence Level Number​  \
# 0               S                SL                      1
# 1               D               MTH                      2
# 2               D               MTH                      2
# 3               D               MTH                      2
# 4               D               MTH                      2
#
#   Sequence Number Code​ Fiscal Year​ Fiscal Quarter Number​ Calendar Year​  \
# 0                     1         2026                      1           2025
# 1                   1.1         2026                      1           2025
# 2                   1.2         2026                      1           2025
# 3                   1.3         2026                      1           2025
# 4                   1.4         2026                      1           2025
#
#   Calendar Quarter Number​ Calendar Month Number​ Calendar Day Number​
# 0                        4                     12                   31
# 1                        4                     12                   31
# 2                        4                     12                   31
# 3                        4                     12                   31
# 4                        4                     12                   31
#
# [5 rows x 21 columns]

# %% [markdown]
# ### `spending_df`

# %% [markdown]
# #### Preprocessing

# %%
import requests
import pandas as pd
import time

url = "https://api.usaspending.gov/api/v2/search/spending_by_award/"
start_date = "2024-01-01"
end_date = "2024-12-31"

# %% [markdown]
# Define the fields that will be used for analysis.

# %%
# Define fields and award types
fields = [
    "Award Amount", "Total Outlays", "Award ID",
    "Recipient Name", "Recipient State Code", 
    "Awarding Agency", "Award Type",
    "Start Date", "End Date",
    "Place of Performance State Code",
    "Last Modified Date",
    
    # Additional
    "COVID-19 Obligations", "Infrastructure Obligations",
    "Awarding Sub Agency", "Funding Agency",
    "Description", "NAICS", "CFDA Number"
]

# Separate award type groups
award_groups = {
    "contracts": ["A", "B", "C", "D"],
    "grants": ["02", "03", "04", "05"],
    "loans": ["07", "08"],
    "other": ["06", "09", "10", "11", "-1"]
}

# NY-NJ-CT filter
target_states = ["CT"
#, "NJ", "NY"
]

# %% [markdown]
# These are the definitions for award types.<br>

# %% [markdown]
# <b>Contract Types</b>
#
# A = Definitive Contract (BPA)<br>
# B = Purchase Order<br>
# C = Delivery Order<br>
# D = Definitive Contract<br>
#
# <b>Grant Types</b>
#
# 02 = Block Grant<br>
# 03 = Formula Grant<br>
# 04 = Project Grant<br>
# 05 = Cooperative Agreement<br>
#
# <b>Loan Types</b>
#
# 07 = Direct Loan<br>
# 08 = Guaranteed/Insured Loan

# %% [markdown]
# Creating the payload to attach to the reuqest using POST.

# %% [markdown]
# Begin fetching the data from the USASpending API.
#
# The request orders the return of results by 100 through different pages.
# Results are stored to a variable called `spending_data`. For Milestone 2, only the contracts from Connecticut will be pulled and cleaned. This same process will be used for the `NY` and `NJ` data.

# %% [markdown]
# #### Extraction

# %%
# Fetch all award types for NY-NJ-CT
spending_data = []  # Initialize empty list to store all records from API

# Loop through each award type group (contracts, grants, loans, other)
for group_name, award_types in award_groups.items():
    print(f"\n{'='*60}")
    print(f"Fetching {group_name.upper()}...")  # Show which group is being fetched
    print(f"{'='*60}")
    
    page = 1  # Start at page 1 for each award type group
    
    # Loop through all pages of results
    while True:
        # Building the API request payload
        payload = {
            "filters": {
                # Filter by range, award type code and states NY, NJ and CT 
                # (just CT for Milestone 2)
                "time_period": [{"start_date": start_date, "end_date": end_date}],
                "award_type_codes": award_types,
                "recipient_locations": [
                    {"country": "USA", "state": state} for state in target_states
                ]
            },
            # Specify which data fields to return, page number
            #    and api_limit page (limit is 100)
            "fields": fields,
            "page": page,
            "limit": 100
        }
        
        # Make POST request to USAspending API
        response = requests.post(url, json=payload)
        
        # Check if request was successful, parse the results
        #   and save it to the running results

        if response.status_code == 200:
            data = response.json()
            results = data.get('results', [])
            
            # If no results returned, we've reached the end
            if not results:
                break
            
            # This is where we actually extend the spending_data
            #   variable with the running results
            spending_data.extend(results)

            # Show progress
            print(f"Page {page}: {len(spending_data):,} total records")
            
            # Check if there are more pages available
            if not data.get('page_metadata', {}).get('hasNext', False):
                break
            
            # Move to next page
            page += 1
            # Wait 0.3 seconds between requests
            #   for safety reasons
            time.sleep(0.3)
        else:
            # If request failed, print error and stop
            print(f"Error {response.status_code}: {response.text}")
            break

# Final summary after all award type groups are fetched
print(f"\n{'='*60}")
print(f"Total records collected: {len(spending_data):,}")
print(f"{'='*60}")
# Out:
# ============================================================
# Fetching CONTRACTS...
# ============================================================
# Page 1: 100 total records
# Page 2: 200 total records
# Page 3: 300 total records
# Page 4: 400 total records
# Page 5: 500 total records
# Page 6: 600 total records
# Page 7: 700 total records
# Page 8: 800 total records
# Page 9: 900 total records
# Page 10: 1,000 total records
# Page 11: 1,100 total records
# Page 12: 1,200 total records
# Page 13: 1,300 total records
# Page 14: 1,400 total records
# Page 15: 1,500 total records
# Page 16: 1,600 total records
# Page 17: 1,700 total records
# Page 18: 1,800 total records
# Page 19: 1,900 total records
# Page 20: 2,000 total records
# Page 21: 2,100 total records
# Page 22: 2,200 total records
# Page 23: 2,300 total records
# Page 24: 2,400 total records
# Page 25: 2,500 total records
# Page 26: 2,600 total records
# Page 27: 2,700 total records
# Page 28: 2,800 total records
# Page 29: 2,900 total records
# Page 30: 3,000 total records
# Page 31: 3,100 total records
# Page 32: 3,200 total records
# Page 33: 3,300 total records
# Page 34: 3,400 total records
# Page 35: 3,500 total records
# Page 36: 3,600 total records
# Page 37: 3,700 total records
# Page 38: 3,800 total records
# Page 39: 3,900 total records
# Page 40: 4,000 total records
# Page 41: 4,100 total records
# Page 42: 4,200 total records
# Page 43: 4,300 total records
# Page 44: 4,400 total records
# Page 45: 4,500 total records
# Page 46: 4,600 total records
# Page 47: 4,700 total records
# Page 48: 4,800 total records
# Page 49: 4,900 total records
# Page 50: 5,000 total records
# Page 51: 5,100 total records
# Page 52: 5,200 total records
# Page 53: 5,300 total records
# Page 54: 5,400 total records
# Page 55: 5,500 total records
# Page 56: 5,600 total records
# Page 57: 5,700 total records
# Page 58: 5,800 total records
# Page 59: 5,900 total records
# Page 60: 6,000 total records
# Page 61: 6,100 total records
# Page 62: 6,200 total records
# Page 63: 6,300 total records
# Page 64: 6,400 total records
# Page 65: 6,500 total records
# Page 66: 6,600 total records
# Page 67: 6,700 total records
# Page 68: 6,800 total records
# Page 69: 6,900 total records
# Page 70: 7,000 total records
# Page 71: 7,100 total records
# Page 72: 7,200 total records
# Page 73: 7,300 total records
# Page 74: 7,400 total records
# Page 75: 7,500 total records
# Page 76: 7,600 total records
# Page 77: 7,700 total records
# Page 78: 7,800 total records
# Page 79: 7,900 total records
# Page 80: 8,000 total records
# Page 81: 8,100 total records
# Page 82: 8,200 total records
# Page 83: 8,300 total records
# Page 84: 8,400 total records
# Page 85: 8,500 total records
# Page 86: 8,600 total records
# Page 87: 8,700 total records
# Page 88: 8,800 total records
# Page 89: 8,900 total records
# Page 90: 9,000 total records
# Page 91: 9,100 total records
# Page 92: 9,200 total records
# Page 93: 9,300 total records
# Page 94: 9,400 total records
# Page 95: 9,500 total records
# Page 96: 9,600 total records
# Page 97: 9,700 total records
# Page 98: 9,800 total records
# Page 99: 9,900 total records
# Page 100: 10,000 total records
#
# ============================================================
# Fetching GRANTS...
# ============================================================
# Page 1: 10,100 total records
# Page 2: 10,200 total records
# Page 3: 10,300 total records
# Page 4: 10,400 total records
# Page 5: 10,500 total records
# Page 6: 10,600 total records
# Page 7: 10,700 total records
# Page 8: 10,800 total records
# Page 9: 10,900 total records
# Page 10: 11,000 total records
# Page 11: 11,100 total records
# Page 12: 11,200 total records
# Page 13: 11,300 total records
# Page 14: 11,400 total records
# Page 15: 11,500 total records
# Page 16: 11,600 total records
# Page 17: 11,700 total records
# Page 18: 11,800 total records
# Page 19: 11,900 total records
# Page 20: 12,000 total records
# Page 21: 12,100 total records
# Page 22: 12,200 total records
# Page 23: 12,300 total records
# Page 24: 12,400 total records
# Page 25: 12,500 total records
# Page 26: 12,600 total records
# Page 27: 12,700 total records
# Page 28: 12,800 total records
# Page 29: 12,900 total records
# Page 30: 13,000 total records
# Page 31: 13,100 total records
# Page 32: 13,200 total records
# Page 33: 13,300 total records
# Page 34: 13,400 total records
# Page 35: 13,500 total records
# Page 36: 13,600 total records
# Page 37: 13,700 total records
# Page 38: 13,800 total records
# Page 39: 13,900 total records
# Page 40: 14,000 total records
# Page 41: 14,100 total records
# Page 42: 14,200 total records
# Page 43: 14,300 total records
# Page 44: 14,400 total records
# Page 45: 14,500 total records
# Page 46: 14,600 total records
# Page 47: 14,700 total records
# Page 48: 14,800 total records
# Page 49: 14,900 total records
# Page 50: 15,000 total records
# Page 51: 15,100 total records
# Page 52: 15,200 total records
# Page 53: 15,300 total records
# Page 54: 15,400 total records
# Page 55: 15,500 total records
# Page 56: 15,600 total records
# Page 57: 15,700 total records
# Page 58: 15,800 total records
# Page 59: 15,900 total records
# Page 60: 16,000 total records
# Page 61: 16,100 total records
# Page 62: 16,200 total records
# Page 63: 16,300 total records
# Page 64: 16,400 total records
# Page 65: 16,500 total records
# Page 66: 16,600 total records
# Page 67: 16,700 total records
# Page 68: 16,800 total records
# Page 69: 16,900 total records
# Page 70: 17,000 total records
# Page 71: 17,100 total records
# Page 72: 17,200 total records
# Page 73: 17,300 total records
# Page 74: 17,400 total records
# Page 75: 17,500 total records
# Page 76: 17,600 total records
# Page 77: 17,700 total records
# Page 78: 17,800 total records
# Page 79: 17,900 total records
# Page 80: 18,000 total records
# Page 81: 18,100 total records
# Page 82: 18,200 total records
# Page 83: 18,300 total records
# Page 84: 18,400 total records
# Page 85: 18,500 total records
# Page 86: 18,600 total records
# Page 87: 18,700 total records
# Page 88: 18,800 total records
# Page 89: 18,900 total records
# Page 90: 19,000 total records
# Page 91: 19,100 total records
# Page 92: 19,183 total records
#
# ============================================================
# Fetching LOANS...
# ============================================================
# Error 400: {"detail":"Sort value 'Award Amount' not found in Loan Award mappings: ['Award ID', 'Recipient Name', 'Recipient DUNS Number', 'recipient_id', 'Awarding Agency', 'Awarding Agency Code', 'Awarding Sub Agency', 'Awarding Sub Agency Code', 'Funding Agency', 'Funding Agency Code', 'Funding Sub Agency', 'Funding Sub Agency Code', 'Place of Performance City Code', 'Place of Performance State Code', 'Place of Performance Country Code', 'Place of Performance Zip5', 'Description', 'Last Modified Date', 'Base Obligation Date', 'prime_award_recipient_id', 'generated_internal_id', 'def_codes', 'COVID-19 Obligations', 'COVID-19 Outlays', 'Infrastructure Obligations', 'Infrastructure Outlays', 'Recipient UEI', 'naics_code', 'naics_description', 'psc_code', 'psc_description', 'cfda_number', 'cfda_program_title', 'sub_cfda_program_titles', 'recipient_location_city_name', 'recipient_location_state_code', 'recipient_location_country_name', 'recipient_location_address_line1', 'recipient_location_address_line2', 'recipient_location_address_line3', 'sub_recipient_location_city_name', 'sub_recipient_location_state_code', 'sub_recipient_location_country_name', 'sub_recipient_location_address_line1', 'pop_city_name', 'pop_state_code', 'pop_country_name', 'sub_pop_city_name', 'sub_pop_state_code', 'sub_pop_country_name', 'Issued Date', 'Loan Value', 'Subsidy Cost', 'SAI Number', 'CFDA Number', 'Assistance Listings']"}
#
# ============================================================
# Fetching OTHER...
# ============================================================
# Error 422: {"message":"'award_type_codes' must only contain types from one group.","award_type_groups":{"contracts":{"A":"BPA Call","B":"Purchase Order","C":"Delivery Order","D":"Definitive Contract"},"loans":{"07":"Direct Loan","08":"Guaranteed/Insured Loan","F003":"Direct Loan","F004":"Loan Guarantee"},"idvs":{"IDV_A":"GWAC Government Wide Acquisition Contract","IDV_B":"IDC Multi-Agency Contract, Other Indefinite Delivery Contract","IDV_B_A":"IDC Indefinite Delivery Contract / Requirements","IDV_B_B":"IDC Indefinite Delivery Contract / Indefinite Quantity","IDV_B_C":"IDC Indefinite Delivery Contract / Definite Quantity","IDV_C":"FSS Federal Supply Schedule","IDV_D":"BOA Basic Ordering Agreement","IDV_E":"BPA Blanket Purchase Agreement"},"grants":{"02":"Block Grant","03":"Formula Grant","04":"Project Grant","05":"Cooperative Agreement","F001":"Grant","F002":"Cooperative Agreement"},"other_financial_assistance":{"06":"Direct Payment for Specified Use","10":"Direct Payment with Unrestricted Use","F006":"Direct Payment for Specified Use","F007":"Direct Payment with Unrestricted Use"},"direct_payments":{"09":"Insurance","11":"Other Financial Assistance","-1":"Not Specified","F005":"Indemnity / Insurance (non-loan)","F008":"Asset Forfeiture / Equitable Sharing","F009":"Sale, Exchange, or Donation of Property and Goods","F010":"Other Financial Assistance"}}}
#
# ============================================================
# Total records collected: 19,183
# ============================================================

# %% [markdown]
# #### Conversion

# %%
spending_df = pd.DataFrame(spending_data)
# Checking if the field we filtered the data on,
#   "Last Modified Date" is in the dataframe.

# %%
spending_df['Place of Performance State Code'] \
    .value_counts() \
    .reset_index(name='count') \
    .rename(columns={'index': 'Place of Performance State Code'}).head()
# Out:
#   Place of Performance State Code  count
# 0                              CT  16269
# 1                              IL    408
# 2                              DC    291
# 3                              MD    176
# 4                              MA    163

# %% [markdown]
# Analyze results. Since what's being pulled is all that was <b>received</b>, state codes other than CT are listed. `Place of Performane Code` is a good measurement becuase it shows where the service was executed.

# %%
# Display the filter parameters used
print("")
print("DATA COLLECTION FILTERS")
print("")
start_date = spending_df['Last Modified Date'].min()
end_date   = spending_df['Last Modified Date'].max()
print(f"Date Range: {start_date} to {end_date}")
print(f"Target States: {', '.join(target_states)}")
print(f"Award Groups: {', '.join(award_groups.keys())}")
print(f"Total Records Collected: {len(spending_df):,}")
# Out:
# DATA COLLECTION FILTERS
#
# Date Range: 2024-01-02T12:14:17 to 2026-03-06T19:18:36.604902
# Target States: CT
# Award Groups: contracts, grants, loans, other
# Total Records Collected: 19,183

# %% [markdown]
# According to the above analysis, the earliest date for an award is 2024-01-02 as expected from our filters. The most recent modified date is March 6th, 2026 as of March 8th 2026, todays date.

# %% [markdown]
# ### `wage_df`

# %% [markdown]
# #### Extraction

# %% [markdown]
# Read in the CSV wage data file and convert to DataFrame.

# %%
wage_data = pd.read_csv('data/wages_summary_2024.csv')

# %% [markdown]
# Notice how this CSV contains mixed data types that we'll need to address.

# %%
# check the datastypes of each field
wage_data.dtypes
# Out:
# area_fips                                int64
# own_code                                 int64
# industry_code                              str
# agglvl_code                              int64
# size_code                                int64
# year                                     int64
# qtr                                        str
# disclosure_code                            str
# area_title                                 str
# own_title                                  str
# industry_title                             str
# agglvl_title                               str
# size_title                                 str
# annual_avg_estabs_count                  int64
# annual_avg_emplvl                        int64
# total_annual_wages                       int64
# taxable_annual_wages                     int64
# annual_contributions                     int64
# annual_avg_wkly_wage                     int64
# avg_annual_pay                           int64
# lq_disclosure_code                         str
# lq_annual_avg_estabs_count             float64
# lq_annual_avg_emplvl                   float64
# lq_total_annual_wages                  float64
# lq_taxable_annual_wages                float64
# lq_annual_contributions                float64
# lq_annual_avg_wkly_wage                float64
# lq_avg_annual_pay                      float64
# oty_disclosure_code                        str
# oty_annual_avg_estabs_count_chg          int64
# oty_annual_avg_estabs_count_pct_chg    float64
# oty_annual_avg_emplvl_chg                int64
# oty_annual_avg_emplvl_pct_chg          float64
# oty_total_annual_wages_chg               int64
# oty_total_annual_wages_pct_chg         float64
# oty_taxable_annual_wages_chg             int64
# oty_taxable_annual_wages_pct_chg       float64
# oty_annual_contributions_chg             int64
# oty_annual_contributions_pct_chg       float64
# oty_annual_avg_wkly_wage_chg             int64
# oty_annual_avg_wkly_wage_pct_chg       float64
# oty_avg_annual_pay_chg                   int64
# oty_avg_annual_pay_pct_chg             float64
# dtype: object

# %% [markdown]
# #### Conversion

# %%
wage_df = pd.DataFrame(wage_data)

# %% [markdown]
# It looks like the field `area_fips` has a datatype of `object`, which may cause issues in processing down the line. String type is much better suited for this field.

# %%
wage_df['area_fips'] = wage_df['area_fips'].astype(str)

# %% [markdown]
# Check the new type, it is now a string.

# %%
wage_df['area_fips'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %% [markdown]
# All sources have been extracted and made into a DataFrame.

# %% [markdown]
# ## Step 2: Formatting, Filtering, Cleaning

# %% [markdown]
# ### Date Formatting

# %% [markdown]
# A few formatting issues should be addressed. There are mismatching date formats in the the treasury and wage dataframes. The ideal date format for `pandas` is `YYYY-MM-DD` (ISO 8601). Any dates should be converted to this format if they are not. Date formatting will be done by detecting the values of `datetime64` fields in each dataframe.

# %% [markdown]
# #### `treasury_df`

# %%
col = 'Record Datemm/dd/yyyy - mm/dd/yyyy'

# Check treasury_df dtype
print("Current dtype:", treasury_df[col].dtype)

print("Sample values:")
print(treasury_df[col].head())
# Out:
# Current dtype: str
# Sample values:
# 0    12/31/2025
# 1    12/31/2025
# 2    12/31/2025
# 3    12/31/2025
# 4    12/31/2025
# Name: Record Datemm/dd/yyyy - mm/dd/yyyy, dtype: str

# %% [markdown]
# The `datetime` conversion will be executed using the `pd.to_datetime()` method.

# %%
treasury_df[col] = pd.to_datetime(
    treasury_df[col],
    format='%m/%d/%Y',
    errors='raise'
)

# %%
# Check treasury_df dtype
print("Current dtype:", treasury_df[col].dtype)

print("Sample values:")
print(treasury_df[col].head())
# Out:
# Current dtype: datetime64[us]
# Sample values:
# 0   2025-12-31
# 1   2025-12-31
# 2   2025-12-31
# 3   2025-12-31
# 4   2025-12-31
# Name: Record Datemm/dd/yyyy - mm/dd/yyyy, dtype: datetime64[us]

# %% [markdown]
# While we're here, let's clean the header name as well. It should be just "Record Date".

# %%
treasury_df.rename(
    columns={'Record Datemm/dd/yyyy - mm/dd/yyyy': 'Record Date'},
    inplace=True
)

treasury_df['Record Date'].dtype
# Out:
# dtype('<M8[us]')

# %% [markdown]
# #### `spending_df`

# %% [markdown]
# Before cleaning, explore the types of original date columns.

# %%
cols = ['Start Date', 'End Date', 'Last Modified Date']

# Check spending_df dtype
for col in cols:
    print(f"\nColumn: {col}")
    print("Current dtype:", spending_df[col].dtype)
    print("Sample values:")
    print(spending_df[col].head())
# Out:
# Column: Start Date
# Current dtype: str
# Sample values:
# 0    2017-02-14
# 1    2017-09-21
# 2    2012-04-13
# 3    2008-12-22
# 4    2003-08-14
# Name: Start Date, dtype: str
#
# Column: End Date
# Current dtype: str
# Sample values:
# 0    2036-06-02
# 1    2031-12-31
# 2    2026-03-01
# 3    2023-08-31
# 4    2025-05-06
# Name: End Date, dtype: str
#
# Column: Last Modified Date
# Current dtype: str
# Sample values:
# 0    2026-02-20T11:05:03
# 1    2025-11-26T10:27:56
# 2    2025-12-04T11:03:38
# 3    2025-11-17T09:29:09
# 4    2025-05-13T15:18:06
# Name: Last Modified Date, dtype: str

# %% [markdown]
# They are all strings. We must convert them by iterating through the list of fields defined earlier and performing the same `.to_datetime()` operation.

# %%
for col in cols:
    spending_df[col] = pd.to_datetime(
        spending_df[col],
        format='mixed',
        errors='raise'
    )

# %% [markdown]
# Perform another check.

# %%
# Check spending_df dtype
for col in cols:
    print(f"\nColumn: {col}")
    print("Current dtype:", spending_df[col].dtype)
    print("Sample values:")
    print(spending_df[col].head())
# Out:
# Column: Start Date
# Current dtype: datetime64[us]
# Sample values:
# 0   2017-02-14
# 1   2017-09-21
# 2   2012-04-13
# 3   2008-12-22
# 4   2003-08-14
# Name: Start Date, dtype: datetime64[us]
#
# Column: End Date
# Current dtype: datetime64[us]
# Sample values:
# 0   2036-06-02
# 1   2031-12-31
# 2   2026-03-01
# 3   2023-08-31
# 4   2025-05-06
# Name: End Date, dtype: datetime64[us]
#
# Column: Last Modified Date
# Current dtype: datetime64[us]
# Sample values:
# 0   2026-02-20 11:05:03
# 1   2025-11-26 10:27:56
# 2   2025-12-04 11:03:38
# 3   2025-11-17 09:29:09
# 4   2025-05-13 15:18:06
# Name: Last Modified Date, dtype: datetime64[us]

# %% [markdown]
# #### `wage_df`

# %% [markdown]
# This dataframe contains one `year` field which should be in an `int` format.

# %%
col = 'year'

# Check treasury_df dtype
print("Current dtype:", wage_df[col].dtype)

print("Sample values:")
print(wage_df[col].head())
# Out:
# Current dtype: int64
# Sample values:
# 0    2024
# 1    2024
# 2    2024
# 3    2024
# 4    2024
# Name: year, dtype: int64

# %% [markdown]
# This one looks good.

# %% [markdown]
# ### Column Filtering

# %% [markdown]
# Much of the data that was pulled back from it's raw source, we won't need. Filtering the data will help keep only what is needed for the analysis.

# %% [markdown]
# #### `treasury_df`

# %% [markdown]
# To start, anything that isnt a month of the year in `Classification` should be removed. Fiscal year and Year-To-Date options exist for this column as well, which will without a doubt skew the data.

# %%
# Check unique rows in Classification column
treasury_df['Classification Description​'].unique()
# Out:
# <StringArray>
# [     'FY 2025',      'October',     'November',     'December',
#       'January',     'February',        'March',        'April',
#           'May',         'June',         'July',       'August',
#     'September', 'Year-to-Date',      'FY 2026',      'FY 2024']
# Length: 16, dtype: str

# %%
# Define valid months
valid_months = [
    'January', 'February', 'March', 'April', 'May', 'June',
    'July', 'August', 'September', 'October', 'November', 'December'
]

# %% [markdown]
# Remove non-month rows in `Classification`.

# %%
# Keep only rows where Classification Description is a valid month
treasury_df = treasury_df[treasury_df['Classification Description​'].isin(valid_months)]

# Drop any NaNs if needed
treasury_df = treasury_df.dropna(subset=['Classification Description​'])

# %%
treasury_df['Classification Description​'].unique()
# Out:
# <StringArray>
# [  'October',  'November',  'December',   'January',  'February',     'March',
#      'April',       'May',      'June',      'July',    'August', 'September']
# Length: 12, dtype: str

# %% [markdown]
# Each of these months are attached to a dollar amount.

# %% [markdown]
# Now we'll begin filtering out unneeded fields.

# %% [markdown]
# There are invisible characters in the treasury data, which is expected from a web scraping source. Using `.replace()` to trim these columns will fix it.

# %%
# treasury_df.columns.tolist()

# %%
treasury_df.columns = [col.replace('\u200b', '') for col in treasury_df.columns]

# %% [markdown]
# For treasury_df retained columns will be `Record Date`, `Classification ID`, `Classification Description`, `Current Month Gross Receipts Amount`, `Current Month Gross Outlay Amount`, `Current Month Deficit Surplus Amount`.

# %%
t_retained = [
    'Record Date',                        # Date of the treasury record
    'Classification ID',                  # Unique numeric ID for the classification
    'Classification Description',         # Description of the classification (e.g., month/category)
    'Current Month Gross Receipts Amount',# Total receipts for the current month
    'Current Month Gross Outlay Amount',  # Total outlays/expenditures for the current month
    'Current Month Deficit Surplus Amount'# Net deficit or surplus for the current month
]

treasury_df = treasury_df[t_retained]

# %%
treasury_df.columns.tolist()
# Out:
# ['Record Date',
#  'Classification ID',
#  'Classification Description',
#  'Current Month Gross Receipts Amount',
#  'Current Month Gross Outlay Amount',
#  'Current Month Deficit Surplus Amount']

# %% [markdown]
# The treasury data came from the HTML file, so it's not expected that dtypes are applied other than the datetimes we just processed.

# %%
treasury_df['Record Date'] = pd.to_datetime(treasury_df['Record Date'], errors='coerce')
treasury_df['Classification ID'] = pd.to_numeric(treasury_df['Classification ID'], errors='coerce')
treasury_df['Classification Description'] = treasury_df['Classification Description'].astype(str)
treasury_df['Current Month Gross Receipts Amount'] = pd.to_numeric(treasury_df['Current Month Gross Receipts Amount'].astype(str).str.replace(',', '').str.replace('$',''), errors='coerce')
treasury_df['Current Month Gross Outlay Amount'] = pd.to_numeric(treasury_df['Current Month Gross Outlay Amount'].astype(str).str.replace(',', '').str.replace('$',''), errors='coerce')
treasury_df['Current Month Deficit Surplus Amount'] = pd.to_numeric(treasury_df['Current Month Deficit Surplus Amount'].astype(str).str.replace(',', '').str.replace('$',''), errors='coerce')

# %% [markdown]
# Now checking the datypes, they should no longer all be `str`.

# %%
treasury_df.dtypes
# Out:
# Record Date                             datetime64[us]
# Classification ID                                int64
# Classification Description                         str
# Current Month Gross Receipts Amount            float64
# Current Month Gross Outlay Amount              float64
# Current Month Deficit Surplus Amount           float64
# dtype: object

# %% [markdown]
# #### `spending_df`

# %% [markdown]
# Below is a list of the retained columns from the spending dataframe.

# %%
s_retained = [
    'internal_id',                    # Unique internal identifier for the record in the dataset
    'Award Amount',                   # Total monetary value of the award granted
    'Award ID',                        # Government-assigned unique identifier for the award
    'Recipient Name',                  # Name of the individual, company, or organization receiving the award
    'Recipient State Code',            # Two-letter US state code for the recipient’s location
    'Awarding Agency',                 # Federal agency that issued the award
    'Start Date',                      # Date when the award or project period begins
    'End Date',                        # Date when the award or project period ends
    'Place of Performance State Code', # Two-letter US state code where the award’s work will be performed
    'Last Modified Date',              # Most recent date when the award record was updated
    'Awarding Sub Agency',             # Subdivision or office within the awarding agency responsible for the award
    'Funding Agency',                  # Agency providing the funds, may differ from the awarding agency
    'Description',                     # Text description of the purpose, scope, or use of the award
    'NAICS'                            # North American Industry Classification System code 
                                       #    describing the type of business or industry receiving the award
]


spending_df = spending_df[s_retained]

# %%
spending_df.dtypes
# Out:
# internal_id                                 int64
# Award Amount                              float64
# Award ID                                      str
# Recipient Name                                str
# Recipient State Code                       object
# Awarding Agency                               str
# Start Date                         datetime64[us]
# End Date                           datetime64[us]
# Place of Performance State Code               str
# Last Modified Date                 datetime64[us]
# Awarding Sub Agency                           str
# Funding Agency                                str
# Description                                   str
# NAICS                                      object
# dtype: object

# %% [markdown]
# #### `wage_df`

# %% [markdown]
# Below are retained columns from the wage dataframe.

# %%
w_retained = [
    'area_fips',
    'industry_code',
    'year',
    'annual_avg_wkly_wage',
    'total_annual_wages',
    'avg_annual_pay',
    'annual_avg_emplvl',
    'industry_title'
]

wage_df = wage_df[w_retained]

# %%
wage_df = wage_df[wage_df['industry_code'].str.len() == 6]

# %%
wage_df.dtypes
# Out:
# area_fips                 str
# industry_code             str
# year                    int64
# annual_avg_wkly_wage    int64
# total_annual_wages      int64
# avg_annual_pay          int64
# annual_avg_emplvl       int64
# industry_title            str
# dtype: object

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### `treasury_df`

# %% [markdown]
# In the treasury_df, once again, becuase it is web data formatting is not applied. For the dollar amounts in this dataframe to be used for arithmitic, they must be in a numeric data type.

# %%
# Treasury dollar columns
treasury_dollars = [
    'Current Month Gross Receipts Amount',
    'Current Month Gross Outlay Amount',
    'Current Month Deficit Surplus Amount'
]

# Convert to float
treasury_df[treasury_dollars] = treasury_df[treasury_dollars].apply(pd.to_numeric, errors='coerce')

# Verify
print(treasury_df.dtypes)
# Out:
# Record Date                             datetime64[us]
# Classification ID                                int64
# Classification Description                         str
# Current Month Gross Receipts Amount            float64
# Current Month Gross Outlay Amount              float64
# Current Month Deficit Surplus Amount           float64
# dtype: object

# %% [markdown]
# Shorten column headers to comfortably query from a table.

# %%
treasury_df.columns
# Out:
# Index(['Record Date', 'Classification ID', 'Classification Description',
#        'Current Month Gross Receipts Amount',
#        'Current Month Gross Outlay Amount',
#        'Current Month Deficit Surplus Amount'],
#       dtype='str')

# %%
treasury_df.columns = ['Date', 'ClassID', 'Month', 'GrossReceipts', 'GrossOutlayAmt', 'DeficitSurplusAmt']
treasury_df.head()
# Out:
#         Date   ClassID     Month  GrossReceipts  GrossOutlayAmt  \
# 1 2025-12-31  57633931   October   3.267702e+11    5.842203e+11
# 2 2025-12-31  57633935  November   3.017543e+11    6.685171e+11
# 3 2025-12-31  57633940  December   4.544147e+11    5.411463e+11
# 4 2025-12-31  57633942   January   5.132943e+11    6.419345e+11
# 5 2025-12-31  57633946  February   2.964237e+11    6.034409e+11
#
#    DeficitSurplusAmt
# 1       2.574500e+11
# 2       3.667628e+11
# 3       8.673162e+10
# 4       1.286402e+11
# 5       3.070172e+11

# %% [markdown]
# #### Data Validation

# %% [markdown]
# Sometimes in API data, a column will take the form of a dictionary. Pandas cannot read this as it is, so any dictionaries should be converted to a tuple.

# %%
spending_df.map(type).eq(dict).any()
# this expression checks for dicts in each columns
# Out:
# internal_id                        False
# Award Amount                       False
# Award ID                           False
# Recipient Name                     False
# Recipient State Code               False
# Awarding Agency                    False
# Start Date                         False
# End Date                           False
# Place of Performance State Code    False
# Last Modified Date                 False
# Awarding Sub Agency                False
# Funding Agency                     False
# Description                        False
# NAICS                               True
# dtype: bool

# %% [markdown]
# #### Dictionary to Tuple Conversion

# %%
# Convert NAICS to a plain string (handles dicts, tuples, and anything else)
spending_df['NAICS'] = spending_df['NAICS'].apply(
    lambda x: x.get('code') if isinstance(x, dict)
    else x[0] if isinstance(x, tuple) and len(x) > 0
    else str(x) if x is not None
    else None
)

# %%
duplicates = spending_df[spending_df.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [internal_id, Award Amount, Award ID, Recipient Name, Recipient State Code, Awarding Agency, Start Date, End Date, Place of Performance State Code, Last Modified Date, Awarding Sub Agency, Funding Agency, Description, NAICS]
# Index: []

# %% [markdown]
# #### Trimming

# %% [markdown]
# Wherever there is the word "Corporation" will be replaced with "Corp." to save horizontal space.

# %%
spending_df = spending_df.replace("CORPORATION", "CORP.", regex=True)

# %% [markdown]
# #### Replacing

# %% [markdown]
# Expore the final results of the datasets,

# %% [markdown]
# To update for current events, the name "Department of Defense" will be changed to "Department of War".

# %%
spending_df = spending_df.replace("Department of Defense", "Department of War", regex=True)
# spending_df.head()

# %%
for col in spending_df.columns:
    types = spending_df[col].dropna().map(type).unique()
    if any(t in [dict, tuple, list] for t in types):
        print(f"Problem column: {col} -> {types}")

# %% [markdown]
# #### Filling NaNs

# %%
# Fill NaNs in numeric columns only for each dataframe

numeric_cols = treasury_df.select_dtypes(include='number').columns
treasury_df[numeric_cols] = treasury_df[numeric_cols].fillna(0)

numeric_cols = spending_df.select_dtypes(include='number').columns
spending_df[numeric_cols] = spending_df[numeric_cols].fillna(0)

numeric_cols = wage_df.select_dtypes(include='number').columns
wage_df[numeric_cols] = wage_df[numeric_cols].fillna(0)

# Verify
print("treasury NaNs:\n", treasury_df.isnull().sum())
print("\nspending NaNs:\n", spending_df.isnull().sum())
print("\nwage NaNs:\n", wage_df.isnull().sum())
# Out:
# treasury NaNs:
#  Date                 0
# ClassID              0
# Month                0
# GrossReceipts        0
# GrossOutlayAmt       0
# DeficitSurplusAmt    0
# dtype: int64
#
# spending NaNs:
#  internal_id                            0
# Award Amount                           0
# Award ID                               0
# Recipient Name                         0
# Recipient State Code               19183
# Awarding Agency                        0
# Start Date                          2206
# End Date                            1589
# Place of Performance State Code      274
# Last Modified Date                     0
# Awarding Sub Agency                    0
# Funding Agency                        93
# Description                           15
# NAICS                               9198
# dtype: int64
#
# wage NaNs:
#  area_fips               0
# industry_code           0
# year                    0
# annual_avg_wkly_wage    0
# total_annual_wages      0
# avg_annual_pay          0
# annual_avg_emplvl       0
# industry_title          0
# dtype: int64

# %% [markdown]
# #### Type Casting

# %%
# treasury_df
treasury_df['GrossReceipts'] = pd.to_numeric(treasury_df['GrossReceipts'], errors='coerce').fillna(0)
treasury_df['GrossOutlayAmt'] = pd.to_numeric(treasury_df['GrossOutlayAmt'], errors='coerce').fillna(0)
treasury_df['DeficitSurplusAmt'] = pd.to_numeric(treasury_df['DeficitSurplusAmt'], errors='coerce').fillna(0)
treasury_df['ClassID'] = pd.to_numeric(treasury_df['ClassID'], errors='coerce').fillna(0)

# spending_df
spending_df['Award Amount'] = pd.to_numeric(spending_df['Award Amount'], errors='coerce').fillna(0)
spending_df['internal_id'] = pd.to_numeric(spending_df['internal_id'], errors='coerce').fillna(0)

# wage_df
wage_df['annual_avg_wkly_wage'] = pd.to_numeric(wage_df['annual_avg_wkly_wage'], errors='coerce').fillna(0)
wage_df['total_annual_wages'] = pd.to_numeric(wage_df['total_annual_wages'], errors='coerce').fillna(0)
wage_df['industry_code'] = wage_df['industry_code'].astype(str)
wage_df['year'] = pd.to_numeric(wage_df['year'], errors='coerce').fillna(0)
# removed qtr numeric cast, qtr is now 'A' (annual)

# Verify
print("treasury dtypes:\n", treasury_df.dtypes)
print("\nspending dtypes:\n", spending_df.dtypes)
print("\nwage dtypes:\n", wage_df.dtypes)
# Out:
# treasury dtypes:
#  Date                 datetime64[us]
# ClassID                       int64
# Month                           str
# GrossReceipts               float64
# GrossOutlayAmt              float64
# DeficitSurplusAmt           float64
# dtype: object
#
# spending dtypes:
#  internal_id                                 int64
# Award Amount                              float64
# Award ID                                      str
# Recipient Name                                str
# Recipient State Code                       object
# Awarding Agency                               str
# Start Date                         datetime64[us]
# End Date                           datetime64[us]
# Place of Performance State Code               str
# Last Modified Date                 datetime64[us]
# Awarding Sub Agency                           str
# Funding Agency                                str
# Description                                   str
# NAICS                                         str
# dtype: object
#
# wage dtypes:
#  area_fips                 str
# industry_code             str
# year                    int64
# annual_avg_wkly_wage    int64
# total_annual_wages      int64
# avg_annual_pay          int64
# annual_avg_emplvl       int64
# industry_title            str
# dtype: object

# %% [markdown]
# # Step 3: Store in Database

# %% [markdown]
# Now comes the time to store this data so it can be queried.

# %% [markdown]
# To create tables out of each dataframe, the `.to_sql()` function from sqlite is used.

# %%
import sqlite3

# Spin up the SQL connection.
conn = sqlite3.connect('government_spending.db')

# Each dataframe gets its own table, how generous of me.
treasury_df.to_sql('treasury', conn, if_exists='replace', index=False)
spending_df.to_sql('spending', conn, if_exists='replace', index=False)
wage_df.to_sql('wages', conn, if_exists='replace', index=False)

print("Tables written successfully.")
conn.close()
# Out:
# Tables written successfully.

# %% [markdown]
# Creating a SQLite connection object and dropping the government spending DB for testing and reruns.

# %%
conn = sqlite3.connect('government_spending.db')

conn.execute("DROP TABLE IF EXISTS spending_vs_wages")

# %% [markdown]
# In the below query, a new table is being built from the newly created wage and spending tables. In the wages table, "9000" is the FIPS code for Connecticut, which has a state code of "CT" that is in the spending table.
#
# This is used to compare government spending directly with wages. What would have made the JOIN a lot easier, is if the FIPS code were in the spending table as well. Then we would only need to specify the code, instead of pulling in the "Place of Performance Code" and the FIPS code in two different places in the SQL. Another approach that would've worked is to create a lookup table with all states and their FIPS code.

# %%
query = """
CREATE TABLE spending_vs_wages AS
SELECT
    s."Place of Performance State Code"     AS state,
    COUNT(s."Award Amount")                 AS num_awards,
    ROUND(SUM(s."Award Amount"), 2)         AS total_award_amount,
    ROUND(AVG(s."Award Amount"), 2)         AS avg_award_amount,
    s.NAICS                                 AS naics_code,
    w.industry_title                        AS industry_name,
    ROUND(AVG(w.annual_avg_wkly_wage), 2)   AS avg_weekly_wage,
    ROUND(AVG(w.total_annual_wages), 2)     AS avg_annual_wages,
    ROUND(AVG(w.avg_annual_pay), 2)         AS avg_annual_pay,
    w.year
FROM spending s
JOIN wages w
    ON CAST(s.NAICS AS TEXT) = CAST(w.industry_code AS TEXT)
    AND w.area_fips = 9000
WHERE s."Place of Performance State Code" = 'CT'
GROUP BY
    s."Place of Performance State Code", s.NAICS, w.year
"""

conn.execute(query)
conn.commit()

# %% [markdown]
# We'll perform a quick SELECT on the recently created table above.

# %%
df = pd.read_sql("SELECT * FROM spending_vs_wages", conn)
print(f"Rows: {len(df)}")
print(df.head())
conn.close()
# Out:
# Rows: 270
#   state  num_awards  total_award_amount  avg_award_amount naics_code  \
# 0    CT           5          1003682.80         200736.56     112310
# 1    CT           1            36000.00          36000.00     112990
# 2    CT           1            98215.00          98215.00     113310
# 3    CT           1            79439.80          79439.80     221118
# 4    CT           6         51394587.32        8565764.55     221122
#
#                                   industry_name  avg_weekly_wage  \
# 0           NAICS 112310 Chicken egg production           1337.0
# 1      NAICS 112990 All other animal production              0.0
# 2                          NAICS 113310 Logging              0.0
# 3  NAICS 221118 Other electric power generation              0.0
# 4      NAICS 221122 Electric power distribution           1239.0
#
#    avg_annual_wages  avg_annual_pay  year
# 0        29755444.0         69536.0  2024
# 1               0.0             0.0  2024
# 2               0.0             0.0  2024
# 3               0.0             0.0  2024
# 4        19147749.5         64416.5  2024

# %% [markdown]
# # Step 4: Data Visualization

# %% [markdown]
# Two visuals are created from this data; a bar chart showing spending by industry, and a scatter plot showing Average Award Amount by Weekly Wage. Additional data cleaning should be performed to force numeric types on numeric columns and drop NAICs that are NaN.

# %%
import matplotlib.pyplot as plt

# Force numeric types
df['total_award_amount'] = pd.to_numeric(df['total_award_amount'], errors='coerce').fillna(0)
df['avg_award_amount'] = pd.to_numeric(df['avg_award_amount'], errors='coerce').fillna(0)
df['avg_weekly_wage'] = pd.to_numeric(df['avg_weekly_wage'], errors='coerce').fillna(0)
df['num_awards'] = pd.to_numeric(df['num_awards'], errors='coerce').fillna(0)

# Drop NaN naics for cleaner charts
df_naics = df.dropna(subset=['naics_code'])

# %% [markdown]
# From the below graph, we can tell that the aeronautical manufacturing industry had the lowest Award Amount of the analysis, while Ship building and reparing was the highest funded industry code.

# %%
fig = plt.figure(figsize=(14, 6))
# Creating the bar chart data by industry name
bar_data = (
    df_naics.groupby('industry_name')['total_award_amount']
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

plt.bar(bar_data['industry_name'],
        bar_data['total_award_amount'] / 1e9,
        color='steelblue', edgecolor='black')
plt.title('Total Government Spending by Industry (Top 10)', fontsize=13)
plt.xlabel('Industry')
plt.ylabel('Total Award Amount ($ Billions)')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_24776/496454397.py:19: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# Average Award Amount over Average Weekly Wage shows the amount that was awarded to the different industries code over weekly wages.

# %%
scatter_data = (
    df_naics.groupby('industry_name')
    .agg(avg_award=('avg_award_amount', 'mean'),
         avg_wage=('avg_weekly_wage', 'mean'),
         num_awards=('num_awards', 'sum'))
    .reset_index()
)

# Convert to numeric to plot properly.
scatter_data['avg_award'] = pd.to_numeric(scatter_data['avg_award'], errors='coerce').fillna(0)
scatter_data['avg_wage'] = pd.to_numeric(scatter_data['avg_wage'], errors='coerce').fillna(0)
scatter_data['num_awards'] = pd.to_numeric(scatter_data['num_awards'], errors='coerce').fillna(1)

scatter_data = scatter_data[scatter_data['avg_award'] < 1000000]

# %% [markdown]
# Filtering in awards that are under $1M.

# %%
# creating the scatter plot
fig = plt.figure(figsize=(16, 7))
plt.scatter(
    scatter_data['avg_wage'],
    scatter_data['avg_award'] / 1e6,
    s=scatter_data['num_awards'].astype(float) * 2,
    alpha=0.6,
    color='steelblue',
    edgecolors='black'
)
for _, row in scatter_data.iterrows(): # Iterating through industry name and plotting average wage and award
    plt.annotate(row['industry_name'],
                 (row['avg_wage'], row['avg_award'] / 1e6),
                 textcoords='offset points', xytext=(5, 5), fontsize=7)

# Nicely plot each industry name
plt.title('Avg Award Amount vs Avg Weekly Wage by Industry\n(bubble size = number of awards)', fontsize=13)
plt.xlabel('Average Weekly Wage ($)')
plt.ylabel('Average Award Amount ($ Millions)')
plt.tight_layout()
plt.savefig('spending_vs_wages.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# The above scatter plot visualizes the different industries over average weekly wages. Some of the higher paid industries are software publishers, research and development in nanotechnology, and wholesale trade agents/brokers.

# %% [markdown]
# # Step 5: Reflection and Ethical Implications

# %% [markdown]
# In this project we made several formatting, filtering and data cleaning changes. Filtering out fields that won't be used in the analysis, trimming "CORPORATION" to "CORP.", searching for duplicates and updating the Department of Defense to reflect the officially reinstated title were among these transformations. To plot the data, further cleaning was needed. NaNs still existed in the wage data, which was preventing matplotlib from plotting the data. Even after the data had been visualized in the scatter plot, restrictions were needed to avoid including outliers. In the end, we were able to visualize Award Amount over Wages and FIPS code by storing multi-sourced data into a database. Much was learned about the different ways data can conatin inconsistencies and discrepencies even when taken directly from an API, flat file from a government webiste or from web scaping most of all.
#
# Regulatory guidelines for the USASpending webite source are similar, if not identical to that of the U.S Treasury data and BLS Wage data under the <a href="https://fiscal.treasury.gov/foia.html">Freedom of Information Act"</a>. Risks created based on the transformations include incorrecly identifing a Recipient Name or neglecting to remove NaNs. Confusion can be avoided by only showing the data from this notebook to internal teams after ensuring it is cleaned to ones best ability. Reckless assumptions about a population could cause bias. This data was ethically sourced and verified, as it is from a credible government institution.
#
# A few assumptions were made for this analysis, to limit the number of rows dealt with. All findings in this analysis were restricted to the state of Connecticut, which means all receiving Award Amounts should be for CT aside from contracts performed in another state but received by Connecticut. The timeframe of this analysis is restricted from early 2024 to current day. Award amounts will only include contracts that were active through, or modified after January 1st 2024.
#
# To conclude, a data pipeline was created to pull in wage, government spending and monthly treasury statement data to analyze Award Amounts by Wage and FIPS code. This revealed which codes and wage groups were awarded the highest to lowest amounts within the scope of the analysis.

# %% [markdown]
# <b>Below are all three dataframes in their current filtered, formatted and cleaned state.</b>

# %%
spending_df.head(5)
# Out:
#    internal_id  Award Amount       Award ID       Recipient Name  \
# 0    309506838  3.465196e+10  N0002417C2100  ELECTRIC BOAT CORP.
# 1    309506843  2.431381e+10  N0002417C2117  ELECTRIC BOAT CORP.
# 2    309505151  1.962774e+10  N0002412C2115  ELECTRIC BOAT CORP.
# 3    309504148  1.623878e+10  N0002409C2104  ELECTRIC BOAT CORP.
# 4    309501862  9.397332e+09  N0002403C2101  ELECTRIC BOAT CORP.
#
#   Recipient State Code    Awarding Agency Start Date   End Date  \
# 0                 None  Department of War 2017-02-14 2036-06-02
# 1                 None  Department of War 2017-09-21 2031-12-31
# 2                 None  Department of War 2012-04-13 2026-03-01
# 3                 None  Department of War 2008-12-22 2023-08-31
# 4                 None  Department of War 2003-08-14 2025-05-06
#
#   Place of Performance State Code  Last Modified Date     Awarding Sub Agency  \
# 0                              CT 2026-02-20 11:05:03  Department of the Navy
# 1                              CT 2025-11-26 10:27:56  Department of the Navy
# 2                              CT 2025-12-04 11:03:38  Department of the Navy
# 3                              CT 2025-11-17 09:29:09  Department of the Navy
# 4                              CT 2025-05-13 15:18:06  Department of the Navy
#
#       Funding Agency                                        Description  \
# 0  Department of War            SSN 802 AND 803 LONG LEAD TIME MATERIAL
# 1  Department of War                   COLUMBIA CLASS DESIGN COMPLETION
# 2  Department of War                    SSN 792 LONG LEAD TIME MATERIAL
# 3  Department of War  CONSTRUCTION OF VIRGINIA CLASS BLOCK III SUBMA...
# 4  Department of War                                                NaN
#
#     NAICS
# 0  336611
# 1  541330
# 2  336611
# 3  336611
# 4  336611

# %%
treasury_df.head(5)
# Out:
#         Date   ClassID     Month  GrossReceipts  GrossOutlayAmt  \
# 1 2025-12-31  57633931   October   3.267702e+11    5.842203e+11
# 2 2025-12-31  57633935  November   3.017543e+11    6.685171e+11
# 3 2025-12-31  57633940  December   4.544147e+11    5.411463e+11
# 4 2025-12-31  57633942   January   5.132943e+11    6.419345e+11
# 5 2025-12-31  57633946  February   2.964237e+11    6.034409e+11
#
#    DeficitSurplusAmt
# 1       2.574500e+11
# 2       3.667628e+11
# 3       8.673162e+10
# 4       1.286402e+11
# 5       3.070172e+11

# %%
wage_df.head(5)
# Out:
#    area_fips industry_code  year  annual_avg_wkly_wage  total_annual_wages  \
# 17      9000        336611  2024                  2505            53677923
# 22      9000        445110  2024                   850             1978753
# 26      9000        455110  2024                   677             4908613
# 30      9000        457110  2024                   675              341977
# 35      9000        491110  2024                  1331           547176903
#
#     avg_annual_pay  annual_avg_emplvl  \
# 17          130260                412
# 22           44218                 45
# 26           35187                140
# 30           35075                 10
# 35           69235               7903
#
#                                        industry_title
# 17           NAICS 336611 Ship building and repairing
# 22  NAICS 445110 Supermarkets and other grocery re...
# 26                     NAICS 455110 Department stores
# 30  NAICS 457110 Gasoline stations with convenienc...
# 35                        NAICS 491110 Postal service
